# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df1 = pd.read_csv("Toronto_apartment.csv")
df1.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#          Lat       Long      Price
# 0  43.581639 -79.648193  $2,450.00
# 1  43.643051 -79.391643  $2,150.00
# 2  43.660605 -79.378635  $1,950.00
# 3  43.641087 -79.381405  $2,900.00
# 4  43.652487 -79.389622  $1,800.00

# %%
df2 = df1.drop(['Lat', 'Long'], axis = 'columns')
df2.shape
# Out:
# (1124, 5)

# %%
df2.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#        Price
# 0  $2,450.00
# 1  $2,150.00
# 2  $1,950.00
# 3  $2,900.00
# 4  $1,800.00

# %%
df2.Price= df2.Price.str.replace('$', '')
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7560/1920498576.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2.Price= df2.Price.str.replace('$', '')

# %%
df2.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#       Price
# 0  2,450.00
# 1  2,150.00
# 2  1,950.00
# 3  2,900.00
# 4  1,800.00

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df2.Price =df2.Price.str.replace(',','')

# %%
df2.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#      Price
# 0  2450.00
# 1  2150.00
# 2  1950.00
# 3  2900.00
# 4  1800.00

# %%
df2.Price.apply(is_float).head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Price, dtype: bool

# %%
type(df2.Price)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(df2.Price)

# %%
s
# Out:
# 0       2450.00
# 1       2150.00
# 2       1950.00
# 3       2900.00
# 4       1800.00
#          ...
# 1119    3000.00
# 1120    1200.00
# 1121    1800.00
# 1122    2200.00
# 1123    2150.00
# Name: Price, Length: 1124, dtype: object

# %%
df3 =df2.copy()

# %%
df3.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#      Price
# 0  2450.00
# 1  2150.00
# 2  1950.00
# 3  2900.00
# 4  1800.00

# %%
df3.Den.dtypes
# Out:
# dtype('int64')

# %%
df3.Price =pd.to_numeric(df3.Price)

# %%
df3.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#     Price
# 0  2450.0
# 1  2150.0
# 2  1950.0
# 3  2900.0
# 4  1800.0

# %%
df3['price_Per_room'] = df3.Price/(df3.Bedroom + df3.Den)

# %%
df3.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#     Price  price_Per_room
# 0  2450.0          1225.0
# 1  2150.0          1075.0
# 2  1950.0          1950.0
# 3  2900.0          1450.0
# 4  1800.0          1800.0

# %%
df3_stats = df3['price_Per_room'].describe()

# %%
df3_stats
# Out:
# count      1124.000000
# mean       2995.104982
# std       27544.722722
# min          49.500000
# 25%        1150.000000
# 50%        1500.000000
# 75%        1975.000000
# max      535000.000000
# Name: price_Per_room, dtype: float64

# %%
df3.Address = df3.Address.apply(lambda x: x.strip())
stat = df3.Address.value_counts(ascending = False)
stat
# Out:
# 10 York Street, Toronto, ON, M5J 0E1                                          17
# 70 Temperance St, Toronto, ON M5H 0B1, Canada                                 15
# 3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada    13
# 89 McGill Street, Toronto, ON, M5B 0B1                                        12
# 87 Peter St, Toronto, ON M5V 0P1, Canada                                      11
#                                                                               ..
# 23 Wyndham St, Toronto, ON M6K 1R8, Canada                                     1
# 39 Upper Duke Crescent, Unionville, ON L6G 0B8, Canada                         1
# 350 Wellington St W, Toronto, ON M5V 3W9, Canada                               1
# 20 King St E, Cobourg, ON K9A 1K7, Canada                                      1
# 561 Sherbourne St, Toronto, ON M4X 0A1, Canada                                 1
# Name: Address, Length: 653, dtype: int64

# %%
df3.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1        361 Front St W, Toronto, ON M5V 3R5, Canada
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0      80 St Patrick St, Toronto, ON M5T 2X6, Canada
#
#     Price  price_Per_room
# 0  2450.0          1225.0
# 1  2150.0          1075.0
# 2  1950.0          1950.0
# 3  2900.0          1450.0
# 4  1800.0          1800.0

# %%
df3.Address = df3.Address.apply(lambda x: x.strip())
stat = df3.Address.value_counts(ascending = False)
stat
# Out:
# 10 York Street, Toronto, ON, M5J 0E1                                          17
# 70 Temperance St, Toronto, ON M5H 0B1, Canada                                 15
# 3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada    13
# 89 McGill Street, Toronto, ON, M5B 0B1                                        12
# 87 Peter St, Toronto, ON M5V 0P1, Canada                                      11
#                                                                               ..
# 23 Wyndham St, Toronto, ON M6K 1R8, Canada                                     1
# 39 Upper Duke Crescent, Unionville, ON L6G 0B8, Canada                         1
# 350 Wellington St W, Toronto, ON M5V 3W9, Canada                               1
# 20 King St E, Cobourg, ON K9A 1K7, Canada                                      1
# 561 Sherbourne St, Toronto, ON M4X 0A1, Canada                                 1
# Name: Address, Length: 653, dtype: int64

# %%
stat.values.sum()
# Out:
# 1124

# %%
len(stat[stat>10])
# Out:
# 5

# %%
len(stat)
# Out:
# 653

# %%
len(stat[stat<=10])
# Out:
# 648

# %%
stat_less_than_10 = stat[stat<=10]
stat_less_than_10
# Out:
# 89 McGill St, Toronto, ON M5B 1H3, Canada                 10
# 2386  New Street, Burlington, ON, L7R 1J7                  9
# 2304  Weston Road, Toronto, ON, M9N 1Z3                    9
# 460 Adelaide St E, Toronto, ON M5A 1N4, Canada             9
# 12 York St, Toronto, ON M5J 2Z2, Canada                    9
#                                                           ..
# 23 Wyndham St, Toronto, ON M6K 1R8, Canada                 1
# 39 Upper Duke Crescent, Unionville, ON L6G 0B8, Canada     1
# 350 Wellington St W, Toronto, ON M5V 3W9, Canada           1
# 20 King St E, Cobourg, ON K9A 1K7, Canada                  1
# 561 Sherbourne St, Toronto, ON M4X 0A1, Canada             1
# Name: Address, Length: 648, dtype: int64

# %%
len(df3.Address.unique())
# Out:
# 653

# %%
df3.Address = df3.Address.apply(lambda x: 'other' if x in stat_less_than_10 else x)

# %%
df3.head()
# Out:
#    Bedroom  Bathroom  Den                                            Address  \
# 0        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 1        1       1.0    1                                              other
# 2        1       1.0    0             89 McGill Street, Toronto, ON, M5B 0B1
# 3        2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 4        1       1.0    0                                              other
#
#     Price  price_Per_room
# 0  2450.0          1225.0
# 1  2150.0          1075.0
# 2  1950.0          1950.0
# 3  2900.0          1450.0
# 4  1800.0          1800.0

# %%
df3.shape
# Out:
# (1124, 6)

# %%
df3.price_Per_room.describe()
# Out:
# count      1124.000000
# mean       2995.104982
# std       27544.722722
# min          49.500000
# 25%        1150.000000
# 50%        1500.000000
# 75%        1975.000000
# max      535000.000000
# Name: price_Per_room, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('Address'):
        m = np.mean(subdf.price_Per_room)
        st = np.std(subdf.price_Per_room)
        reduced_df = subdf[(subdf.price_Per_room > (m-st)) & (subdf.price_Per_room<=(m+st))]
        df_out = pd.concat([df_out, reduced_df], ignore_index = True)
    return df_out

# %%
df4 = remove_pps_outliers(df3)

# %%
df4.shape
# Out:
# (1101, 6)

# %%
df4.price_Per_room.describe()
# Out:
# count     1101.000000
# mean      1567.383893
# std        778.711404
# min         49.500000
# 25%       1150.000000
# 50%       1500.000000
# 75%       1950.000000
# max      18450.000000
# Name: price_Per_room, dtype: float64

# %%
df4.Bedroom[df4.Bedroom>2]
# Out:
# 126     3
# 226     3
# 278     3
# 279     3
# 297     3
# 347     3
# 399     3
# 400     3
# 414     3
# 454     3
# 463     3
# 565     3
# 566     3
# 584     3
# 600     3
# 647     3
# 678     3
# 679     3
# 686     3
# 731     3
# 764     3
# 811     3
# 834     3
# 841     3
# 846     3
# 881     3
# 887     3
# 895     3
# 901     3
# 908     3
# 920     3
# 940     3
# 958     3
# 1021    3
# 1041    3
# 1042    3
# 1073    3
# 1095    3
# 1096    3
# Name: Bedroom, dtype: int64

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)
plt.hist(df4.price_Per_room, rwidth = 0.8)
plt.xlabel("Price per room")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
df4.head(100)
# Out:
#     Bedroom  Bathroom  Den                               Address   Price  \
# 0         2       2.0    0  10 York Street, Toronto, ON, M5J 0E1  2900.0
# 1         2       2.0    0  10 York Street, Toronto, ON, M5J 0E1  2900.0
# 2         2       2.0    0  10 York Street, Toronto, ON, M5J 0E1  2900.0
# 3         2       2.0    0  10 York Street, Toronto, ON, M5J 0E1  2900.0
# 4         2       2.0    0  10 York Street, Toronto, ON, M5J 0E1  2900.0
# ..      ...       ...  ...                                   ...     ...
# 95        1       1.0    0                                 other  1700.0
# 96        1       1.0    0                                 other  1500.0
# 97        1       1.0    0                                 other  2299.0
# 98        2       2.0    0                                 other  3200.0
# 99        1       1.0    0                                 other  2550.0
#
#     price_Per_room
# 0           1450.0
# 1           1450.0
# 2           1450.0
# ...

# %%
df4 = df4.drop_duplicates()

# %%
df4.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df4.shape
# Out:
# (346, 6)

# %%
df5 = df4.copy()

# %%
df5 = df5.Address.drop_duplicates

# %%
df5.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7560/2111707123.py in <module>
# ----> 1 df5.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
df4.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df6 = df4.copy()

# %%
df6.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
con = df6.Address.drop_duplicates

# %%
con
# Out:
# <bound method Series.drop_duplicates of 0                    10 York Street, Toronto, ON, M5J 0E1
# 9       3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14      3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 21          70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28          70 Temperance St, Toronto, ON M5H 0B1, Canada
#                               ...
# 1083                                                other
# 1085                                                other
# 1087                                                other
# 1095                                                other
# 1096                                                other
# Name: Address, Length: 346, dtype: object>

# %%
df4.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df5 = df4.copy()

# %%
df5.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df5['Address'] = df5['Address'].drop_duplicates()

# %%
df5.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                                NaN
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                                NaN
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df5.shape
# Out:
# (346, 6)

# %%
df5.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                                NaN
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                                NaN
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df5.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                                NaN
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                                NaN
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
store = df5.Address.replace({"NaN": "Other"}, inplace=True)
store

# %%
df5.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                                NaN
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                                NaN
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df6= df5.copy()

# %%
df6["Address"] = df6["Address"].replace({"NaN" : "Other"}, inplace =True)

# %%
df6.head()
# Out:
#     Bedroom  Bathroom  Den Address   Price  price_Per_room
# 0         2       2.0    0    None  2900.0          1450.0
# 9         2       2.0    0    None  2450.0          1225.0
# 14        2       2.0    0    None  2300.0          1150.0
# 21        1       1.0    0    None  1900.0          1900.0
# 28        1       1.0    0    None  2050.0          2050.0

# %%
df6 = df5.copy()

# %%
df6.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                                NaN
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                                NaN
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df6.isnull().sum()
# Out:
# Bedroom             0
# Bathroom            0
# Den                 0
# Address           340
# Price               0
# price_Per_room      0
# dtype: int64

# %%
df6.Address = df6.Address.fillna("Other")

# %%
df6.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                              Other
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                              Other
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
df6[df6.Bathroom>2]
# Out:
#       Bedroom  Bathroom  Den Address   Price  price_Per_room
# 686         3       3.0    0   Other  1300.0      433.333333
# 811         3       3.0    0   Other  2500.0      833.333333
# 827         2       3.0    0   Other  6500.0     3250.000000
# 841         3       2.5    0   Other  1800.0      600.000000
# 847         2       3.0    0   Other  2800.0     1400.000000
# 881         3       3.0    0   Other  4500.0     1500.000000
# 931         2       2.5    0   Other  9750.0     4875.000000
# 1021        3       3.0    0   Other  4900.0     1633.333333

# %%
df6[df6.Bathroom>df6.Bedroom +1]
# Out:
# Empty DataFrame
# Columns: [Bedroom, Bathroom, Den, Address, Price, price_Per_room]
# Index: []

# %%
df6.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                              Other
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                              Other
#
#      Price  price_Per_room
# 0   2900.0          1450.0
# 9   2450.0          1225.0
# 14  2300.0          1150.0
# 21  1900.0          1900.0
# 28  2050.0          2050.0

# %%
dummies = pd.get_dummies(df6.Address)
dummies.head(3)
# Out:
#     10 York Street, Toronto, ON, M5J 0E1  \
# 0                                      1
# 9                                      0
# 14                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# 0                                                   0
# 9                                                   1
# 14                                                  0
#
#     70 Temperance St, Toronto, ON M5H 0B1, Canada  \
# 0                                               0
# 9                                               0
# 14                                              0
#
#     87 Peter St, Toronto, ON M5V 0P1, Canada  \
# 0                                          0
# 9                                          0
# 14                                         0
#
#     89 McGill Street, Toronto, ON, M5B 0B1  Other  other
# 0                                        0      0      0
# ...

# %%
dummies.Other.describe()
# Out:
# count    346.000000
# mean       0.982659
# std        0.130728
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Other, dtype: float64

# %%
dummies.other.describe()
# Out:
# count    346.00000
# mean       0.00289
# std        0.05376
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000
# Name: other, dtype: float64

# %%
dummies['89 McGill Street, Toronto, ON, M5B 0B1'].describeribe()
# Out:
# count    346.00000
# mean       0.00289
# std        0.05376
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000
# Name: 89 McGill Street, Toronto, ON, M5B 0B1, dtype: float64

# %%
dummies2 = dummies.drop(['other'], axis = 'columns')
dummies2.head()
# Out:
#     10 York Street, Toronto, ON, M5J 0E1  \
# 0                                      1
# 9                                      0
# 14                                     0
# 21                                     0
# 28                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# 0                                                   0
# 9                                                   1
# 14                                                  0
# 21                                                  0
# 28                                                  0
#
#     70 Temperance St, Toronto, ON M5H 0B1, Canada  \
# 0                                               0
# 9                                               0
# 14                                              0
# 21                                              1
# 28                                              0
#
#     87 Peter St, Toronto, ON M5V 0P1, Canada  \
# ...

# %%
df7 = pd.concat([df6, dummies.drop('Other','other', axis = 'columns')], axis = 'columns')
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_7560/191698916.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7 = pd.concat([df6, dummies.drop('Other','other', axis = 'columns')], axis = 'columns')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7560/191698916.py in <module>
# ----> 1 df7 = pd.concat([df6, dummies.drop('Other','other', axis = 'columns')], axis = 'columns')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: drop() got multiple values for argument 'axis'

# %%
df7.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                              Other
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                              Other
#
#      Price  price_Per_room  10 York Street, Toronto, ON, M5J 0E1  \
# 0   2900.0          1450.0                                     1
# 9   2450.0          1225.0                                     0
# 14  2300.0          1150.0                                     0
# 21  1900.0          1900.0                                     0
# 28  2050.0          2050.0                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# ...

# %%
df7.other.describe()
# Out:
# count    346.00000
# mean       0.00289
# std        0.05376
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max        1.00000
# Name: other, dtype: float64

# %%
df8 = df7.drop("Address", axis ='columns')
df8.head()
# Out:
#     Bedroom  Bathroom  Den   Price  price_Per_room  \
# 0         2       2.0    0  2900.0          1450.0
# 9         2       2.0    0  2450.0          1225.0
# 14        2       2.0    0  2300.0          1150.0
# 21        1       1.0    0  1900.0          1900.0
# 28        1       1.0    0  2050.0          2050.0
#
#     10 York Street, Toronto, ON, M5J 0E1  \
# 0                                      1
# 9                                      0
# 14                                     0
# 21                                     0
# 28                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# 0                                                   0
# 9                                                   1
# 14                                                  0
# 21                                                  0
# 28                                                  0
#
# ...

# %%
df8 = df7.drop("price_Per_room", axis ='columns')

# %%
df8.head()
# Out:
#     Bedroom  Bathroom  Den                                            Address  \
# 0         2       2.0    0               10 York Street, Toronto, ON, M5J 0E1
# 9         2       2.0    0  3985 Grand Park Drive, 3985 Grand Park Dr, Mis...
# 14        2       2.0    0                                              Other
# 21        1       1.0    0      70 Temperance St, Toronto, ON M5H 0B1, Canada
# 28        1       1.0    0                                              Other
#
#      Price  10 York Street, Toronto, ON, M5J 0E1  \
# 0   2900.0                                     1
# 9   2450.0                                     0
# 14  2300.0                                     0
# 21  1900.0                                     0
# 28  2050.0                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# 0                                                   0
# 9                                                   1
# ...

# %%
df8 = df8.drop("Address", axis ='columns')

# %%
df8 = df8.drop("other",axis = 'columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7560/3795610771.py in <module>
# ----> 1 df8 = df8.drop("other",axis = 'columns')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
X = df8.drop(['Price'], axis = 'columns')
X.head(3)
# Out:
#     Bedroom  Bathroom  Den  10 York Street, Toronto, ON, M5J 0E1  \
# 0         2       2.0    0                                     1
# 9         2       2.0    0                                     0
# 14        2       2.0    0                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# 0                                                   0
# 9                                                   1
# 14                                                  0
#
#     70 Temperance St, Toronto, ON M5H 0B1, Canada  \
# 0                                               0
# 9                                               0
# 14                                              0
#
#     87 Peter St, Toronto, ON M5V 0P1, Canada  \
# 0                                          0
# 9                                          0
# 14                                         0
#
#     89 McGill Street, Toronto, ON, M5B 0B1
# ...

# %%
y = df8.Price
y.head()
# Out:
# 0     2900.0
# 9     2450.0
# 14    2300.0
# 21    1900.0
# 28    2050.0
# Name: Price, dtype: float64

# %%
len(y)
# Out:
# 346

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.20230589522198772

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.05205194, 0.00141487, 0.33690158, 0.12843307, 0.31964237])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
#                model  best_score                               best_params
# 0  linear_regression    0.167689                      {'normalize': False}
# 1              lasso    0.167937       {'alpha': 2, 'selection': 'random'}
# 2      decision_tree   -0.048127  {'criterion': 'mse', 'splitter': 'best'}

# %%
X.head()
# Out:
#     Bedroom  Bathroom  Den  10 York Street, Toronto, ON, M5J 0E1  \
# 0         2       2.0    0                                     1
# 9         2       2.0    0                                     0
# 14        2       2.0    0                                     0
# 21        1       1.0    0                                     0
# 28        1       1.0    0                                     0
#
#     3985 Grand Park Drive, 3985 Grand Park Dr, Mississauga, ON L5B 0H8, Canada  \
# 0                                                   0
# 9                                                   1
# 14                                                  0
# 21                                                  0
# 28                                                  0
#
#     70 Temperance St, Toronto, ON M5H 0B1, Canada  \
# 0                                               0
# 9                                               0
# 14                                              0
# ...

# %%
def predict_price(Address, Bedroom, Bathroom, Den):
    loc_index = np.where(X.columns == Address)[0][0]
    
    x = np.zeros(len(X.columns))
    x[0] = Bedroom
    x[1] = Bathroom
    x[2] = Den
    if loc_index >=0:
        x[loc_index]=1
    return lr_clf.predict([x])[0]

# %%
predict_price('10 York Street, Toronto, ON, M5J 0E1',2, 2,0)
# Out:
# 2900.0000000000005

# %%
import pickle
with open('Toronto Apartment.pickle', 'wb') as f:
    pickle.dump(lr_clf,f)

# %%
import json
columns= {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
